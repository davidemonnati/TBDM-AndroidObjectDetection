# %%
# !nvidia-smi
# Out:
# Mon Jul 15 16:51:47 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install requests==2.31.0
# !pip install pillow==10.0.1

# %%
# !python -m pip install -r /content/drive/MyDrive/big-data/yolov5/requirements.txt

# %%
# !pip install tqdm
# !pip install IProgress

# %%
from tqdm import tqdm
import IProgress
from ipywidgets import IntProgress
import torch

# %cd /content/drive/MyDrive/big-data/yolov5

torch.cuda.get_arch_list()

# %%
# %cd /content/drive/MyDrive/big-data/yolov5

# !python train.py --img 640 --batch 16 --epochs 20 --data /content/drive/MyDrive/big-data/yolov5/data/images640/data.yaml --weights yolov5s.pt --cache

# %%
# %load_ext tensorboard
# %tensorboard — logdir runs

# %%
pip install ultralytics

# %%
# !python detect.py --weights runs/train/exp4/weights/best.pt --img 640 --conf 0.25 --source data/images/test/images

# %%
# !python /content/drive/MyDrive/big-data/yolov5/export.py --weights /content/drive/MyDrive/big-data/yolov5/runs/train/exp5/weights/best.pt --include tflite

# %% [markdown]
# Analyze model

# %%
# !pip install tflite-support

# %%
# !pip install tensorflow=="2.13.0"

# %%
# !pip install tflite-support

# %%
# !pip install tensorflow==2.9.0

# %% [markdown]
# Requirements for metadata writer

# %%
# !pip install absl-py
# !pip install tensorflow
# !pip install tflite-support
# !pip install flatbuffers==1.12

# %%
# !python /content/metadata_writer_for_image_classifier.py --model_file /content/best-fp16.tflite --label_file /content/labels --export_directory /content/out

# %%
# !pip install -U flatbuffers

# %%
import tensorflow as tf
tf.lite.experimental.Analyzer.analyze(model_path="efficientdet-lite0.tflite")
